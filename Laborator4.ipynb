# %% [markdown]
# # Laborator 4

# %% [markdown]
# ## 1. Exercitii cu Pandas

# %%
import pandas as pd
import csv
#1.A. afisare primele 5 linii din fisier
chipotle = pd.read_csv('chipotle.tsv', sep='\t')
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#B. numarul de date din set
print(chipotle.shape[0]*chipotle.shape[1])
# Out:
# 23110

# %%
#C.
#genereaza statistici
print(chipotle.describe(),"\n")
#informatii despre dataframe, clase, index, tipuri de date, utilizarea memoriei
print(chipotle.info())
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB
# None

# %%
#D.care este umarul de coloane? afisati numele lor
print(len(chipotle.columns), chipotle.columns)
# Out:
# 5 Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#E. Cum e indexat setul de date? sunt valorile din index unice?
print (str(chipotle.index))
idx=pd.Index(chipotle['order_id'])
if(idx.is_unique==False):
    print("Valorile nu sunt unice")
else: print("Valorile sunt unice")
# Out:
# RangeIndex(start=0, stop=4622, step=1)
# Valorile nu sunt unice

# %%
#F.Care sunt marfurile vandute, in ordine alfabetica? Cate sunt?
chipotle.groupby('item_name').size()
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
#G.Cate obiecte (items) au fost comandate, in total - 
#suma pe coloana 'quantity'?
chipotle['quantity'].sum()
# Out:
# 4972

# %%
#H. Transformati intr-un ant dataframe coloana 'item_price' din stringuri in valori
#floating point. Care sunt preturile (minim, maxim, mediu, median) cu care s-a vandut produsul
#'Chicken Crispy Tacos'? Cate astfel de produse au fost comandate in total? Care sunt veniturile obtinute
#din vanzarea acestui produs? 
#Nota: puteti folosi metoda describe() a unui dataframe/series.
chipotle['item_price'].str.strip('$').astype(float)
df-chipotle.loc[chipotle['item_name']=='Chicken Crispy Tacos']
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
#I. Care sunt cele mai comandate 3 marfuri? Folositi groupby() pentru grupare, ne intereseaza cantitatile cele mai mari. 
#x  = chipotle.item_name.value_counts()
vandute=chipotle.groupby('item_name').sum()       
vandute.sort_values(by=['quantity'], ascending=False).head(3)
# Out:
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506

# %%
#J.De cate ori s-a comandat 'Veggie Salad Bowl'?
(chipotle.item_name=='Veggie Salad Bowl').sum()
# Out:
# 18

# %%
#K. De cate ori intr-o comanda s-au cerut mai mult de o 'Canned Soda'?
soda=chipotle.loc[chipotle['item_name']=='Canned Soda']
print(len(soda[soda.quantity>1]))
# Out:
# 20

# %%
#L. Care sunt banii incasati pentru fiecare comanda? atentie, pentru fiecare item comandat 
#trebuie luat in considerare si cantitatea. Puteti crea coloane auxiliare (pret transformat din s
#tring in float, pret total pe acel item = pret_unitar * cantitate etc.)
#comanda=chipotle.groupby(['order_id']).sum()
#comanda

# %% [markdown]
# 1. Incarcati setul de date in format tsv [https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) intr-un obiect Pandas DataFrame.
#     1. Afisati primele 5 linii din tabel
#     1. Care este numarul de date din DataFrame?
#     1. Comparati iesirea metodelor `info()` si `describe()`. (de afisat si de stiut ce afiseaza)
#     1. Care e numarul de coloane? afisati numele lor.
#     1. Cum e indexat setul de date? sunt valorile din index unice?
#     1. Care sunt marfurile vandute, in ordine alfabetica? Cate sunt?
#     1. Cate obiecte (items) au fost comandate, in total - suma pe coloana 'quantity'?
#     1. Transformati intr-un ant dataframe coloana 'item_price' din stringuri in valori floating point. Care sunt preturile (minim, maxim, mediu, median) cu care s-a vandut produsul 'Chicken Crispy Tacos'? Cate astfel de produse au fost comandate in total? Care sunt veniturile obtinute din vanzarea acestui produs? *Nota*: puteti folosi metoda `describe()` a unui dataframe/series.
#     1. Care sunt cele mai comandate 3 marfuri? Folositi `groupby()` pentru grupare, ne intereseaza cantitatile cele mai mari. *Nota:* sectiunea 'Aggregation and Grouping' din ref bibliografica 1 din curs e utila pentru intelegerea agregarilor.
#     1. De cate ori s-a comandat 'Veggie Salad Bowl'?
#     1. De cate ori intr-o comanda s-au cerut mai mult de o 'Canned Soda'?
#     1. Care sunt banii incasati pentru fiecare comanda? atentie, pentru fiecare item comandat trebuie luat in considerare si cantitatea. Puteti crea coloane auxiliare (pret transformat din string in float, pret total pe acel item = pret_unitar * cantitate etc.)
#
# 1. Incarcati setul de date de la [https://raw.githubusercontent.com/jokecamp/FootballData/master/UEFA_European_Championship/Euro%202012/Euro%202012%20stats%20TEAM.csv](https://raw.githubusercontent.com/jokecamp/FootballData/master/UEFA_European_Championship/Euro%202012/Euro%202012%20stats%20TEAM.csv) intr-un obiect Pandas DataFrame.
#     1. Cate echipe au participat la Euro 2012?
#     1. Sa se sorteze echipele dupa numarul de cartonase rosii, apoi dupa cele galbene, descrescator - sortare dupa criteriu dublu.
#     1. Care e numarul mediu de cartonase rosii date? Dar mediana?
#     1. Care sunt echipele care au luat mai multe cartonase rosii decat media?
#     1. Care sunt echipele al caror nume incepe cu litera G? *Indicatie*: documentati-va despre Vectorized String Operations, sectiunea omonima din Ref bib 1 din curs 1.
#     1. Care sunt Shooting accuracy pentru Anglia, Grecia, Rusia?
# 1. Incarcati setul de date de la [https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv). Folosind grupari (`groupby`) dupa o documentare serioasa in sectiunea 'Aggregation and Grouping' din ref bibliografica [1] din primul curs, rezolvati:
#     1. Pe care continent se bea mai multa bere, in medie?
#     1. Pentru fiecare continent sa se afiseze statisticile pentru consumul de vin.
#     1. Sa se tipareasca min, max, media pentru consumul de bere pe fiecare continent. Folositi functia `agg`.

# %%
#3.
#A. Pe care continent se bea mai multa bere, in medie?
df=pd.read_csv("drinks.csv",sep=',')
df.groupby('continent').median().sort_values(ascending=False,by='beer_servings').head(1)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU                 219.0            122.0          128.0
#
#            total_litres_of_pure_alcohol
# continent
# EU                                 10.0

# %%
#B.Pentru fiecare continent sa se afiseze statisticile pentru consumul de vin.
df.groupby('continent')['wine_servings'].max()
# Out:
# continent
# AF    233
# AS    123
# EU    370
# OC    212
# SA    221
# Name: wine_servings, dtype: int64

# %%
#C. Sa se tipareasca min, max, media pentru consumul de bere pe
#fiecare continent. Folositi functia agg.
df.groupby('continent')['beer_servings'].agg(['min', 'max', 'mean'])
#df=df.groupby('continent')
#print(df['beer_servings'].agg(['min', 'max', 'mean']))
# Out:
#            min  max        mean
# continent
# AF           0  376   61.471698
# AS           0  247   37.045455
# EU           0  361  193.777778
# OC           0  306   89.687500
# SA          93  333  175.083333

# %%
#2.
teams=pd.read_csv("teams.csv", sep=',')
teams.head()

#A.Cate echipe au participat la Euro 2012?
print(teams['Team'].count())
# Out:
# 16

# %% [markdown]
# **Precizari**:
# * Predarea se va face in saptamana 25-29 martie 2019.
# * Temele se pot lucra in echipa se se depun in acest caz in repository-urile github create pentru prima tema.
# * Punctajul problemelor va fi precizat in decursul acestei saptamanini, urmariti documentul.

# %%
#B. Sa se sorteze echipele dupa numarul de cartonase rosii, apoi dupa cele galbene, descrescator - sortare dupa criteriu dublu.
teams.sort_values(['Red Cards', 'Yellow Cards'], ascending=[True, False])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 4                France      3               22                24
# 12               Russia      5                9                31
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# 15              Ukraine      2                7                26
# 2               Denmark      4               10                10
# 5               Germany     10               32                32
# ...

# %%
#C.Care e numarul mediu de cartonase rosii date? Dar mediana?
media=teams['Red Cards'].mean()
print(media)
print(teams['Red Cards'].median())
# Out:
# 0.1875
# 0.0

# %%
#D. Care sunt echipele care au luat mai multe cartonase rosii decat media?
#df[df.A.gt(df.B)]
teams[teams['Red Cards']>media]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 6                Greece      5                8                18
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 6              30.7%            19.2%                          32
# 9              39.4%             5.2%                          48
# 11             36.8%             5.2%                          28
#
#     Hit Woodwork  Penalty goals  Penalties not scored      ...       \
# 6              1              1                     1      ...
# 9              0              0                     0      ...
# 11             0              0                     0      ...
#
#     Saves made  Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  \
# 6           13                 65.1%         67             48        12
# ...

# %%
#E. Care sunt echipele al caror nume incepe cu litera G? 
teams[teams['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                     0      ...               10                 62.6%
# 6                     1      ...               13                 65.1%
#
#    Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63             49        12             4          0       15
# 6         67             48        12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# ...

# %%
#F. Care sunt Shooting accuracy pentru Anglia, Grecia, Rusia?
print('England',teams.loc[teams['Team']=='England', 'Shooting Accuracy'].iloc[0])
print('Greece', teams.loc[teams['Team']=='Greece', 'Shooting Accuracy'].iloc[0])
print('Russia',teams.loc[teams['Team']=='Russia', 'Shooting Accuracy'].iloc[0])
# Out:
# England 50.0%
# Greece 30.7%
# Russia 22.5%
